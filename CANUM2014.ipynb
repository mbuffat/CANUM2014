# %%
# %matplotlib inline
# %autosave 0
from numpy import *
from talktools import *
# Out:
# Autosave disabled

# %% [markdown]
# <h1>WEBWORK et SAGECELL</h1>
# <center><h2>des outils web 2.0 pour l’apprentissage<br>
#     de la "programmation scientifique"</h2>
#     <img src="Figures/webwork.png" alt="WebWork" style="width:300px;"/>
# <h2>CANUM 2014</h2>
# <a href="http://ufrmeca.univ-lyon1.fr/~buffat">**Marc BUFFAT**</a> @ univ-lyon1.fr<br>
# *Dpt Mécanique, Université Claude Bernard Lyon 1 *
# </center>

# %% [markdown]
# ## Remerciement
# - projet **WebWork**:<br>
# Delphine Doppler,Claude Inserra, Pierre Valiorgue, Ivana Vinkovic
# - Projet Mooc **INPROS**: <br>
# Violaine Louvet, Michel Kern, Anne Cadiou, Loic Gouarin, Laurence Viry
# - <a href="http://webwork.maa.org">WebWork: http://webwork.maa.org</a>:<br>
# Pr. **Michael Gage**, department of mathematics, university of Rochester
# - <a href="http://www.sagemath.org/eval.html">SageCell: http://www.sagemath.org/eval.html</a><br>
# **Jason Grout**, department of Mathematics and Computer Science, Drake University, Des Moines

# %% [markdown]
# # <a href="http://ipython.org/notebook.html">IPython Notebook</a>

# %%
display(Image(filename="Figures/logoIpython.png"))

# %%
with plt.xkcd():
    R=7.; r=4; d=6; t=linspace(0,8*pi,100)
    x = (R-r)*cos(t)+d*cos( (R-r)*t / r )
    y = (R-r)*sin(t)-d*sin( (R-r)*t / r )
    plt.figure(figsize=(8,6))
    plt.plot(x,y,'r',lw=2)
    plt.axis('equal')
    plt.text(-9,-0.5,"CANUM 2014",fontsize=48,color='c')

# %%
display(HTML('<center><h2>Video externe (YouTube)</h2></center>'))
display(HTML('Simulation pétaflopique sur PRACE'))
display(HTML('transition by-pass (Buffat et al 2013)<br>$\\approx 10^{10}$ modes sur $O(10^{6})$ coeurs<br>'))
from IPython.display import YouTubeVideo
YouTubeVideo('R1I9-vuv1GU',width=800,height=500)
# Out:
# <center><h2>Video externe (YouTube)</h2></center>
# Simulation pétaflopique sur PRACE
# transition by-pass (Buffat et al 2013)<br>$\approx 10^{10}$ modes sur $O(10^{6})$ coeurs<br>
#         <iframe
#             width="800"
#             height=500"
#             src="https://www.youtube.com/embed/R1I9-vuv1GU"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Video locale
# transition by-pass (Buffat et al 2013)<br>
# $\approx 10^{10}$ modes sur $O(10^{6})$ coeurs<br>
# <video controls source src="Figures/FILMHD.ogg" width="800" height="500" type="video/ogg"></video>

# %%
display(HTML('<center><h2>Site WEB</h2></center>'))
url='http://elsa.onera.fr/elsA/gallery/data/dvlong/GAL-07032.html'
website(url,name="Simulation industrielle ELSA ONERA<br>Calcul autour d'un avion complet",width=700,height=400)
# Out:
# <center><h2>Site WEB</h2></center>
# <h2><div sytle="margin-bottom:10px">
# <a href="http://elsa.onera.fr/elsA/gallery/data/dvlong/GAL-07032.html">Simulation industrielle ELSA ONERA<br>Calcul autour d'un avion complet</a>
# </div></h2>
# <iframe src="http://elsa.onera.fr/elsA/gallery/data/dvlong/GAL-07032.html"  width="700" height="400"></iframe>

# %%
display(HTML('<center><h1>Partage sur le web</h1></center>'))
url2="http://ufrmeca.univ-lyon1.fr/~buffat/CANUM2014"
display(HTML('<a href="%s"><h3>%s</h3></a>'%(url2,url2)))
url1="http://nbviewer.ipython.org/url/ufrmeca.univ-lyon1.fr/~buffat/CANUM2014/CANUM2014.ipynb"
display(HTML('<a href="%s"><h3>%s</h3></a>'%(url1,url1)))
url='http://nbviewer.ipython.org/'
website(url,name="Notebook nbviewer",width=800,height=400)
# Out:
# <center><h1>Partage sur le web</h1></center>
# <a href="http://ufrmeca.univ-lyon1.fr/~buffat/CANUM2014"><h3>http://ufrmeca.univ-lyon1.fr/~buffat/CANUM2014</h3></a>
# <a href="http://nbviewer.ipython.org/url/ufrmeca.univ-lyon1.fr/~buffat/CANUM2014/CANUM2014.ipynb"><h3>http://nbviewer.ipython.org/url/ufrmeca.univ-lyon1.fr/~buffat/CANUM2014/CANUM2014.ipynb</h3></a>
# <h2><div sytle="margin-bottom:10px">
# <a href="http://nbviewer.ipython.org/">Notebook nbviewer</a>
# </div></h2>
# <iframe src="http://nbviewer.ipython.org/"  width="800" height="400"></iframe>

# %% [markdown]
# #Plan de l'exposé
#
# 1. Contexte
# 2. Objectif pédagogique
# 3. WebWork
# <img src="Figures/webwork_rectangle.png"/>
# 4. SageCell
# <img src="Figures/sage-banner-02.png"/>
# 5. FLOT (Mooc) INPROS
# <img src="Figures/logo_trans.png" style="width:300px;"/>
# 6. Conclusion

# %% [markdown]
# # Contexte
#
# - La modélisation et la simulation numérique sont devenues des outils essentiels de la recherche et de l'innovation
# - L'université ne prépare pas suffisamment nos étudiants à l'utilisation de ces nouveaux outils
# - La **formation** à la **"programmation scientifique"** et au **"calcul intensif"** (HPC) est un enjeu majeur dans les années à venir (rapport CSCI par O. Pironneau, 2013)
# - En particulier importance de la **formation initiale** en 1er cycle d'université

# %% [markdown]
# ##Programmation scientifique
#
# *"démarche scientifique pour passer d'un problème physique à sa résolution sur un ordinateur"*
#
# ## Démarche scientifique
#  - analyse du problème physique
#  - modèle mathématique
#  - méthode de discrétisation
#  - algorithme de résolution du problème discret
#  - programmation et validation
#  - simulations et analyse des résultats

# %% [markdown]
# ##Enseignement des mathématiques et de la programmation
# <center>*Mathematics (and Science) is not a spectator sport*</center>
#
# ##Constat
# Enseignement classique en présentiel (Licence)
#
# - étudiants de formation très disparate avec un manque de méthode de travail
# - peu de maîtrise de l'outil mathématique
# - peu de maîtrise de la programmation
# - logiciels utilisés en TP peu adaptés (Maple, Matlab, Comsol, ....)

# %% [markdown]
# ##Besoin
# ** apprentissage par la pratique **
# - $\Rightarrow$ exercices pour les étudiants
# - $\Rightarrow$ résolution de  problème pour acquérir méthode et formalisme
# - en dehors des heures encadrés
#
# ##Outils Web 2.0
# - Webwork
# - SageCell
# - IPython notebook

# %% [markdown]
# #WebWork <img src="Figures/webwork_rectangle.png" alt="Webwork" />
# ##système de devoirs en ligne
#
#
# - développé à l'université de Rochester
# - très utilisé dans les enseignements de Maths
# <img src="Figures/MAA.jpeg" width=200/>
# - énorme bibliothèque d'exercices: $\approx 20 000$<br>
# algèbre, probabilité, calculus, equa. diff., algèbre linéaire, analyse complexe,..
#
# - système ouvert (libre) et interfaçable (LMS Moodle, SageCell)

# %% [markdown]
# ##Intérêts de WebWork
# <center><img src="Figures/test.jpg" alt="Webwork" style="height:200px;" /></center>
# ## rendre les devoirs à la maison plus efficaces
#
# - réponse immédiate pour les étudiants
#
# - version individualisée des devoirs
#
# - notation automatique
#
# ##interface WEB
# <a href="http://inpros.univ-lyon1.fr/webwork2">http://inpros.univ-lyon1.fr/webwork2</a>

# %% [markdown]
# ## Webwork <img src="Figures/webwork_rectangle.png" alt="Webwork" />
# ## Problème version PDF
# <img src="Figures/Pble1webwork.png"/>

# %% [markdown]
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" /></center>
# ##Entrée des réponses
# <img src="Figures/Pble2webwork.png"/>

# %% [markdown]
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" /></center>
# ## validation des réponses
# <img src="Figures/Pble3webwork.png"/>

# %% [markdown]
# #Sage <img src="Figures/sage_logo_new.png" alt="SageCell" style="height:60px"/>
#
# ##SageCell=Interface Web à Sage
#
# - **SAGE**:
# collection de logiciels libres:<br>
# Python, Numpy, Mathplotlib, Sympy, Maxima, R, Gap
#
# - cellule de calcul Sage dans une page HTML
# - serveur de calcul SAGE
# - aucune installation locale
# - système ouvert interfaçable (LMS Moodle, WebWork)
#
# **Sage server** <a href="http://sagecellmeca.univ-lyon1.fr:8080/">http://sagecellmeca.univ-lyon1.fr:8080/</a>

# %% [markdown]
# <center><img src="Figures/sage_logo_new.png" alt="SageCell" style="height:60px"/></center>
# ## cellule Sage dans une page html d'un navigateur
# <img src="Figures/PgeSagecell.png"/>

# %% [markdown]
# <center><img src="Figures/sage_logo_new.png" alt="SageCell" style="height:60px"/></center>
# ## execution code Sage
# <img src="Figures/Pge0Sagecell.png" style="width:800px;"/>

# %% [markdown]
# <center><img src="Figures/sage_logo_new.png" alt="SageCell" style="height:60px"/></center>
# ##SageCell: inclusion de code Python
# <img src="Figures/Pge2Sagecell.png"/>

# %% [markdown]
# <center><img src="Figures/sage_logo_new.png" alt="SageCell" style="height:60px"/></center>
# ##SageCell: inclusion de code Python
# <img src="Figures/Pge3Sagecell.png"/>

# %% [markdown]
# #INPROS <img src="Figures/logo_trans.png" alt="INPROS" width="200"/>
#
# **INtroduction à la PROgrammation Scientifique**
#
# Prototype de FLOT <a href='http://inpros.univ-lyon1.fr'>http://inpros.univ-lyon1.fr</a>
#
# ## Projet collaboratif
# - objectif: apprentissage d'une méthodologie en programmation scientifique
# - cours d'initiation (public très large)
# - cours interactif avec mise en pratique
# - accessible à partir d'un simple navigateur
# - utilise Webwork, Sagecell, Ipython

# %%
url='http://inpros.univ-lyon1.fr'
website(url,"MOOC INPROS",width=800,height=500)
# Out:
# <h2><div sytle="margin-bottom:10px">
# <a href="http://inpros.univ-lyon1.fr">MOOC INPROS</a>
# </div></h2>
# <iframe src="http://inpros.univ-lyon1.fr"  width="800" height="500"></iframe>

# %% [markdown]
# <center><img src="Figures/logo_trans.png" alt="INPROS" width="200"/></center>
# ## SageCell dans INPROS
# <img src="Figures/Pge1Sagecell.png" style="width:500px;"/>

# %% [markdown]
# <center><img src="Figures/logo_trans.png" alt="INPROS" width="200"/></center>
# ## Webwork + SageCell dans INPROS
# <img src="Figures/PbleSageWebwork.png"/>

# %% [markdown]
# <center><img src="Figures/logo_trans.png" alt="INPROS" width="200"/></center>
# ## Code de l'exercise
# <img src="Figures/CodeSageWebwork.png" style="width:500px;"/>

# %% [markdown]
# # Conclusion
# ## Webwork/Sage en L3/M1 méca.
# - étudiants travaillent à leur rythme
# - plusieurs tentatives (80 à 100% réussite)
# - mise en place  L1 portail PCSI
# - projet FLOT INPROS

# %% [markdown]
# ## Difficultés
# - temps de mise en oeuvre
# - valorisation pour les enseignants

# %% [markdown]
# #Merci de votre attention !!
# <center>
# <img src="Figures/face_question_mark1.jpg" alt="Questions" style="width:200px;"/><br>
# </center>
# <center><h2>Des questions ?</h2></center>

# %%
R=7.; r=4; d=6; t=linspace(0,8*pi,200)
x = (R-r)*cos(t)+d*cos( (R-r)*t / r )
y = (R-r)*sin(t)-d*sin( (R-r)*t / r )
plt.figure(figsize=(8,6))
plt.title("Hypotrochoide")
plt.plot(x,y,'r',lw=1)
plt.axis('equal')
plt.text(-8,-0.5,"CANUM 2014",fontsize=48,color='c')
